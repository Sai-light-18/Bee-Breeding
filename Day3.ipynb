# %% [markdown]
# <a href="https://colab.research.google.com/github/Sai-light-18/Bee-Breeding/blob/main/Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"This is the day Three"
# Out:
# 'This is the day Three'
